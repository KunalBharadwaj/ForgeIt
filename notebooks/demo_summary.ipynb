# %% [markdown]
# # 📰 Fake News Detection
# ### Model: TF-IDF + Logistic Regression (Explainable AI with LIME)

# %%
with open('results/reports/performance_report.txt') as f:
    print(f.read())

# %%
from IPython.display import Image, display
display(Image('results/plots/confusion_matrix.png'))
display(Image('results/plots/roc.png'))

# %% [markdown]
# ### 👉 LIME explanations (open these in your browser)
# - `results/reports/lime_example_801.html`
# - `results/reports/lime_example_3888.html`
# - any other `lime_example_*.html`
#
# **Interpretation:** Green tokens push towards **real**, red towards **fake**.
